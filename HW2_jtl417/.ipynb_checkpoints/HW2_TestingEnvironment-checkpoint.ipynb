# %%
import pylab as pl
import os
import json
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %pylab inline
pl.rc('font', size=15)

url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=a3847762-5b97-4f9c-bca0-42aa6097224a&VehicleMonitoringDetailLevel=calls&LineRef=B52" 
print (url)
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=a3847762-5b97-4f9c-bca0-42aa6097224a&VehicleMonitoringDetailLevel=calls&LineRef=B52
# {'Siri': {'ServiceDelivery': {'ResponseTimestamp': '2017-09-21T12:22:20.802-04:00',
#    'SituationExchangeDelivery': [],
#    'VehicleMonitoringDelivery': [{'ResponseTimestamp': '2017-09-21T12:22:20.802-04:00',
#      'ValidUntil': '2017-09-21T12:23:20.802-04:00',
#      'VehicleActivity': [{'MonitoredVehicleJourney': {'Bearing': 338.15237,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_24540_B52-114',
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-073300_B52_109'},
#         'JourneyPatternRef': 'MTA_B520040',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:22:21.802-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:22:21.802-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 797.4,
#            'DistanceFromCall': 2.07,
#            'PresentableDistance': 'at stop',
#            'StopsFromCall': 0}},
#          'StopPointName': 'FULTON ST/SMITH ST',
#          'StopPointRef': 'MTA_302945',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:22:20.802-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 797.4,
#              'DistanceFromCall': 2.07,
#              'PresentableDistance': 'at stop',
#              'StopsFromCall': 0}},
#            'StopPointName': 'FULTON ST/SMITH ST',
#            'StopPointRef': 'MTA_302945'},
#           {'ExpectedArrivalTime': '2017-09-21T12:23:47.795-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 986.57,
#              'DistanceFromCall': 191.24,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'FULTON ST/HOYT ST',
#            'StopPointRef': 'MTA_307491'},
#           {'ExpectedArrivalTime': '2017-09-21T12:25:29.321-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1220.03,
#              'DistanceFromCall': 424.71,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302947'},
#           {'ExpectedArrivalTime': '2017-09-21T12:27:00.121-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1393.71,
#              'DistanceFromCall': 598.38,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'FULTON ST/FLATBUSH AV EXT',
#            'StopPointRef': 'MTA_302948'},
#           {'ExpectedArrivalTime': '2017-09-21T12:29:19.402-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1683.32,
#              'DistanceFromCall': 887.99,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'FULTON ST/ASHLAND PL',
#            'StopPointRef': 'MTA_303017'},
#           {'ExpectedArrivalTime': '2017-09-21T12:30:11.292-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1831.55,
#              'DistanceFromCall': 1036.23,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'FULTON ST/LAFAYETTE AV',
#            'StopPointRef': 'MTA_302368'},
#           {'ExpectedArrivalTime': '2017-09-21T12:32:14.492-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2085.33,
#              'DistanceFromCall': 1290.0,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'FULTON ST/S PORTLAND AV',
#            'StopPointRef': 'MTA_302369'},
#           {'ExpectedArrivalTime': '2017-09-21T12:33:06.032-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2214.42,
#              'DistanceFromCall': 1419.09,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GREENE AV/FULTON ST',
#            'StopPointRef': 'MTA_307547'},
#           {'ExpectedArrivalTime': '2017-09-21T12:34:09.632-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2427.7,
#              'DistanceFromCall': 1632.37,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307548'},
#           {'ExpectedArrivalTime': '2017-09-21T12:35:10.832-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2599.71,
#              'DistanceFromCall': 1804.39,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GREENE AV/VANDERBILT AV',
#            'StopPointRef': 'MTA_307549'},
#           {'ExpectedArrivalTime': '2017-09-21T12:36:42.632-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2849.35,
#              'DistanceFromCall': 2054.02,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307550'},
#           {'ExpectedArrivalTime': '2017-09-21T12:37:54.123-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3107.79,
#              'DistanceFromCall': 2312.46,
#              'PresentableDistance': '1.4 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307551'},
#           {'ExpectedArrivalTime': '2017-09-21T12:38:59.523-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3346.41,
#              'DistanceFromCall': 2551.08,
#              'PresentableDistance': '1.6 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307552'},
#           {'ExpectedArrivalTime': '2017-09-21T12:40:03.908-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3579.59,
#              'DistanceFromCall': 2784.26,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'FRANKLIN AV/GREENE AV',
#            'StopPointRef': 'MTA_307553'},
#           {'ExpectedArrivalTime': '2017-09-21T12:41:01.219-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3827.24,
#              'DistanceFromCall': 3031.91,
#              'PresentableDistance': '1.9 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_307674'},
#           {'ExpectedArrivalTime': '2017-09-21T12:41:58.586-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4010.77,
#              'DistanceFromCall': 3215.45,
#              'PresentableDistance': '2.0 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_307675'},
#           {'ExpectedArrivalTime': '2017-09-21T12:42:57.511-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4274.94,
#              'DistanceFromCall': 3479.62,
#              'PresentableDistance': '2.2 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_307676'},
#           {'ExpectedArrivalTime': '2017-09-21T12:44:35.086-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4600.33,
#              'DistanceFromCall': 3805.0,
#              'PresentableDistance': '2.4 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_307677'},
#           {'ExpectedArrivalTime': '2017-09-21T12:45:55.086-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4849.89,
#              'DistanceFromCall': 4054.56,
#              'PresentableDistance': '2.5 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_307678'},
#           {'ExpectedArrivalTime': '2017-09-21T12:47:08.024-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5087.05,
#              'DistanceFromCall': 4291.72,
#              'PresentableDistance': '2.7 miles away',
#              'StopsFromCall': 19}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_307679'},
#           {'ExpectedArrivalTime': '2017-09-21T12:48:38.866-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5326.1,
#              'DistanceFromCall': 4530.77,
#              'PresentableDistance': '2.8 miles away',
#              'StopsFromCall': 20}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_307680'},
#           {'ExpectedArrivalTime': '2017-09-21T12:49:58.666-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5574.85,
#              'DistanceFromCall': 4779.52,
#              'PresentableDistance': '3.0 miles away',
#              'StopsFromCall': 21}},
#            'StopPointName': 'GATES AV/LEWIS AV',
#            'StopPointRef': 'MTA_307681'},
#           {'ExpectedArrivalTime': '2017-09-21T12:51:18.466-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5826.46,
#              'DistanceFromCall': 5031.13,
#              'PresentableDistance': '3.1 miles away',
#              'StopsFromCall': 22}},
#            'StopPointName': 'GATES AV/STUYVESANT AV',
#            'StopPointRef': 'MTA_307682'},
#           {'ExpectedArrivalTime': '2017-09-21T12:52:50.666-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6075.85,
#              'DistanceFromCall': 5280.52,
#              'PresentableDistance': '3.3 miles away',
#              'StopsFromCall': 23}},
#            'StopPointName': 'GATES AV/MALCOLM X BL',
#            'StopPointRef': 'MTA_307683'},
#           {'ExpectedArrivalTime': '2017-09-21T12:53:44.898-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6321.91,
#              'DistanceFromCall': 5526.58,
#              'PresentableDistance': '3.4 miles away',
#              'StopsFromCall': 24}},
#            'StopPointName': 'GATES AV/PATCHEN AV',
#            'StopPointRef': 'MTA_307684'},
#           {'ExpectedArrivalTime': '2017-09-21T12:54:50.411-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6555.96,
#              'DistanceFromCall': 5760.63,
#              'PresentableDistance': '3.6 miles away',
#              'StopsFromCall': 25}},
#            'StopPointName': 'GATES AV/RALPH AV',
#            'StopPointRef': 'MTA_307901'},
#           {'ExpectedArrivalTime': '2017-09-21T12:55:52.411-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6717.8,
#              'DistanceFromCall': 5922.47,
#              'PresentableDistance': '3.7 miles away',
#              'StopsFromCall': 26}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_307686'},
#           {'ExpectedArrivalTime': '2017-09-21T12:57:45.043-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6962.31,
#              'DistanceFromCall': 6166.98,
#              'PresentableDistance': '3.8 miles away',
#              'StopsFromCall': 27}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_307687'},
#           {'ExpectedArrivalTime': '2017-09-21T12:58:55.043-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7131.71,
#              'DistanceFromCall': 6336.38,
#              'PresentableDistance': '3.9 miles away',
#              'StopsFromCall': 28}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_307688'},
#           {'ExpectedArrivalTime': '2017-09-21T12:59:57.027-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7373.59,
#              'DistanceFromCall': 6578.26,
#              'PresentableDistance': '4.1 miles away',
#              'StopsFromCall': 29}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2017-09-21T13:01:01.731-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7576.02,
#              'DistanceFromCall': 6780.69,
#              'PresentableDistance': '4.2 miles away',
#              'StopsFromCall': 30}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2017-09-21T13:01:54.931-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7782.09,
#              'DistanceFromCall': 6986.76,
#              'PresentableDistance': '4.3 miles away',
#              'StopsFromCall': 31}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2017-09-21T13:03:24.297-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8081.37,
#              'DistanceFromCall': 7286.04,
#              'PresentableDistance': '4.5 miles away',
#              'StopsFromCall': 32}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2017-09-21T13:03:59.697-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8231.28,
#              'DistanceFromCall': 7435.95,
#              'PresentableDistance': '4.6 miles away',
#              'StopsFromCall': 33}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.691528, 'Longitude': -73.987527},
#         'VehicleRef': 'MTA NYCT_7266'},
#        'RecordedAtTime': '2017-09-21T12:22:11.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 45.576397,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_22080_B52-109',
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-069300_Q55_304'},
#         'JourneyPatternRef': 'MTA_B520040',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:22:21.802-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:22:21.802-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 7373.59,
#            'DistanceFromCall': 2.81,
#            'PresentableDistance': 'at stop',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/CENTRAL AV',
#          'StopPointRef': 'MTA_307689',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:22:20.802-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7373.59,
#              'DistanceFromCall': 2.81,
#              'PresentableDistance': 'at stop',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2017-09-21T12:23:07.424-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7576.02,
#              'DistanceFromCall': 205.24,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2017-09-21T12:24:00.624-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7782.09,
#              'DistanceFromCall': 411.32,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2017-09-21T12:25:29.990-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8081.37,
#              'DistanceFromCall': 710.6,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2017-09-21T12:26:05.390-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8231.28,
#              'DistanceFromCall': 860.5,
#              'PresentableDistance': '0.5 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.694105, 'Longitude': -73.917537},
#         'VehicleRef': 'MTA NYCT_3975'},
#        'RecordedAtTime': '2017-09-21T12:22:02.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 225.44937,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_28440_B54-212',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-074000_B52_118'},
#         'JourneyPatternRef': 'MTA_B520048',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:22:21.802-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:22:21.802-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 501.59,
#            'DistanceFromCall': 13.51,
#            'PresentableDistance': 'at stop',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/IRVING AV',
#          'StopPointRef': 'MTA_304196',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:22:20.802-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 501.59,
#              'DistanceFromCall': 13.51,
#              'PresentableDistance': 'at stop',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/IRVING AV',
#            'StopPointRef': 'MTA_304196'},
#           {'ExpectedArrivalTime': '2017-09-21T12:23:26.660-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 724.62,
#              'DistanceFromCall': 236.54,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_304197'},
#           {'ExpectedArrivalTime': '2017-09-21T12:24:32.319-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 918.53,
#              'DistanceFromCall': 430.45,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_304198'},
#           {'ExpectedArrivalTime': '2017-09-21T12:25:41.682-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1127.58,
#              'DistanceFromCall': 639.5,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_304199'},
#           {'ExpectedArrivalTime': '2017-09-21T12:27:05.367-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1369.74,
#              'DistanceFromCall': 881.67,
#              'PresentableDistance': '0.5 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_304200'},
#           {'ExpectedArrivalTime': '2017-09-21T12:28:03.668-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1539.93,
#              'DistanceFromCall': 1051.85,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_304201'},
#           {'ExpectedArrivalTime': '2017-09-21T12:29:22.545-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1755.61,
#              'DistanceFromCall': 1267.53,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_308046'},
#           {'ExpectedArrivalTime': '2017-09-21T12:30:49.745-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1901.08,
#              'DistanceFromCall': 1413.01,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GATES AV/RALPH AV',
#            'StopPointRef': 'MTA_304203'},
#           {'ExpectedArrivalTime': '2017-09-21T12:32:25.995-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2178.14,
#              'DistanceFromCall': 1690.06,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GATES AV/PATCHEN AV',
#            'StopPointRef': 'MTA_304204'},
#           {'ExpectedArrivalTime': '2017-09-21T12:33:41.439-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2430.58,
#              'DistanceFromCall': 1942.51,
#              'PresentableDistance': '1.2 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GATES AV/MALCOLM X BL',
#            'StopPointRef': 'MTA_304205'},
#           {'ExpectedArrivalTime': '2017-09-21T12:35:16.039-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2679.29,
#              'DistanceFromCall': 2191.22,
#              'PresentableDistance': '1.4 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GATES AV/STUYVESANT AV',
#            'StopPointRef': 'MTA_304206'},
#           {'ExpectedArrivalTime': '2017-09-21T12:36:21.115-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2883.11,
#              'DistanceFromCall': 2395.04,
#              'PresentableDistance': '1.5 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'GATES AV/LEWIS AV',
#            'StopPointRef': 'MTA_304207'},
#           {'ExpectedArrivalTime': '2017-09-21T12:38:25.315-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3177.93,
#              'DistanceFromCall': 2689.85,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_306530'},
#           {'ExpectedArrivalTime': '2017-09-21T12:39:30.715-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3373.19,
#              'DistanceFromCall': 2885.12,
#              'PresentableDistance': '1.8 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_304209'},
#           {'ExpectedArrivalTime': '2017-09-21T12:41:21.515-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3659.93,
#              'DistanceFromCall': 3171.85,
#              'PresentableDistance': '2.0 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_304210'},
#           {'ExpectedArrivalTime': '2017-09-21T12:42:55.115-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3902.63,
#              'DistanceFromCall': 3414.55,
#              'PresentableDistance': '2.1 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_304211'},
#           {'ExpectedArrivalTime': '2017-09-21T12:44:42.146-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4182.76,
#              'DistanceFromCall': 3694.68,
#              'PresentableDistance': '2.3 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_304212'},
#           {'ExpectedArrivalTime': '2017-09-21T12:46:41.798-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4496.51,
#              'DistanceFromCall': 4008.44,
#              'PresentableDistance': '2.5 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_304213'},
#           {'ExpectedArrivalTime': '2017-09-21T12:48:08.129-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4675.5,
#              'DistanceFromCall': 4187.42,
#              'PresentableDistance': '2.6 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_304214'},
#           {'ExpectedArrivalTime': '2017-09-21T12:49:07.426-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4864.08,
#              'DistanceFromCall': 4376.0,
#              'PresentableDistance': '2.7 miles away',
#              'StopsFromCall': 19}},
#            'StopPointName': 'GATES AV/CLASSON AV',
#            'StopPointRef': 'MTA_307948'},
#           {'ExpectedArrivalTime': '2017-09-21T12:50:47.226-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5156.7,
#              'DistanceFromCall': 4668.62,
#              'PresentableDistance': '2.9 miles away',
#              'StopsFromCall': 20}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307572'},
#           {'ExpectedArrivalTime': '2017-09-21T12:52:09.826-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5398.69,
#              'DistanceFromCall': 4910.61,
#              'PresentableDistance': '3.1 miles away',
#              'StopsFromCall': 21}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307573'},
#           {'ExpectedArrivalTime': '2017-09-21T12:53:40.501-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5656.47,
#              'DistanceFromCall': 5168.39,
#              'PresentableDistance': '3.2 miles away',
#              'StopsFromCall': 22}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307596'},
#           {'ExpectedArrivalTime': '2017-09-21T12:55:17.501-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5908.9,
#              'DistanceFromCall': 5420.83,
#              'PresentableDistance': '3.4 miles away',
#              'StopsFromCall': 23}},
#            'StopPointName': 'GREENE AV/VANDERBILT AV',
#            'StopPointRef': 'MTA_307575'},
#           {'ExpectedArrivalTime': '2017-09-21T12:56:21.004-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6075.28,
#              'DistanceFromCall': 5587.2,
#              'PresentableDistance': '3.5 miles away',
#              'StopsFromCall': 24}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307576'},
#           {'ExpectedArrivalTime': '2017-09-21T12:57:16.473-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6239.48,
#              'DistanceFromCall': 5751.4,
#              'PresentableDistance': '3.6 miles away',
#              'StopsFromCall': 25}},
#            'StopPointName': 'GREENE AV/CUMBERLAND ST',
#            'StopPointRef': 'MTA_307577'},
#           {'ExpectedArrivalTime': '2017-09-21T12:58:56.820-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6482.4,
#              'DistanceFromCall': 5994.32,
#              'PresentableDistance': '3.7 miles away',
#              'StopsFromCall': 26}},
#            'StopPointName': 'FULTON ST/S ELLIOTT PL',
#            'StopPointRef': 'MTA_302427'},
#           {'ExpectedArrivalTime': '2017-09-21T13:00:07.483-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6639.55,
#              'DistanceFromCall': 6151.47,
#              'PresentableDistance': '3.8 miles away',
#              'StopsFromCall': 27}},
#            'StopPointName': 'FULTON ST/FT GREENE PL',
#            'StopPointRef': 'MTA_302428'},
#           {'ExpectedArrivalTime': '2017-09-21T13:01:49.283-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6938.8,
#              'DistanceFromCall': 6450.73,
#              'PresentableDistance': '4.0 miles away',
#              'StopsFromCall': 28}},
#            'StopPointName': 'FULTON ST/HUDSON AV',
#            'StopPointRef': 'MTA_302430'},
#           {'ExpectedArrivalTime': '2017-09-21T13:04:04.883-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7188.7,
#              'DistanceFromCall': 6700.63,
#              'PresentableDistance': '4.2 miles away',
#              'StopsFromCall': 29}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302431'},
#           {'ExpectedArrivalTime': '2017-09-21T13:05:38.283-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7394.01,
#              'DistanceFromCall': 6905.93,
#              'PresentableDistance': '4.3 miles away',
#              'StopsFromCall': 30}},
#            'StopPointName': 'FULTON ST/DUFFIELD ST',
#            'StopPointRef': 'MTA_307492'},
#           {'ExpectedArrivalTime': '2017-09-21T13:07:12.483-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7604.3,
#              'DistanceFromCall': 7116.22,
#              'PresentableDistance': '4.4 miles away',
#              'StopsFromCall': 31}},
#            'StopPointName': 'FULTON ST/JAY ST',
#            'StopPointRef': 'MTA_302433'},
#           {'ExpectedArrivalTime': '2017-09-21T13:10:27.483-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7929.74,
#              'DistanceFromCall': 7441.66,
#              'PresentableDistance': '4.6 miles away',
#              'StopsFromCall': 32}},
#            'StopPointName': 'JORALEMON ST/COURT ST',
#            'StopPointRef': 'MTA_302434'},
#           {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8059.65,
#              'DistanceFromCall': 7571.57,
#              'PresentableDistance': '4.7 miles away',
#              'StopsFromCall': 33}},
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2017-09-21T13:12:04.283-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8097.91,
#              'DistanceFromCall': 7609.83,
#              'PresentableDistance': '4.7 miles away',
#              'StopsFromCall': 34}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
#            'StopPointRef': 'MTA_901463'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.698249, 'Longitude': -73.913467},
#         'VehicleRef': 'MTA NYCT_6543'},
#        'RecordedAtTime': '2017-09-21T12:22:09.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 186.5081,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_20040_B52-106',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-071000_B52_112'},
#         'JourneyPatternRef': 'MTA_B520048',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:22:21.802-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:22:21.802-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 4864.08,
#            'DistanceFromCall': 15.29,
#            'PresentableDistance': 'at stop',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/CLASSON AV',
#          'StopPointRef': 'MTA_307948',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:22:20.802-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4864.08,
#              'DistanceFromCall': 15.29,
#              'PresentableDistance': 'at stop',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/CLASSON AV',
#            'StopPointRef': 'MTA_307948'},
#           {'ExpectedArrivalTime': '2017-09-21T12:23:19.993-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5156.7,
#              'DistanceFromCall': 307.91,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307572'},
#           {'ExpectedArrivalTime': '2017-09-21T12:24:42.593-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5398.69,
#              'DistanceFromCall': 549.9,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307573'},
#           {'ExpectedArrivalTime': '2017-09-21T12:26:13.268-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5656.47,
#              'DistanceFromCall': 807.68,
#              'PresentableDistance': '0.5 miles away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307596'},
#           {'ExpectedArrivalTime': '2017-09-21T12:27:50.268-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5908.9,
#              'DistanceFromCall': 1060.11,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GREENE AV/VANDERBILT AV',
#            'StopPointRef': 'MTA_307575'},
#           {'ExpectedArrivalTime': '2017-09-21T12:28:53.771-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6075.28,
#              'DistanceFromCall': 1226.49,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307576'},
#           {'ExpectedArrivalTime': '2017-09-21T12:29:49.240-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6239.48,
#              'DistanceFromCall': 1390.69,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GREENE AV/CUMBERLAND ST',
#            'StopPointRef': 'MTA_307577'},
#           {'ExpectedArrivalTime': '2017-09-21T12:31:29.587-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6482.4,
#              'DistanceFromCall': 1633.61,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'FULTON ST/S ELLIOTT PL',
#            'StopPointRef': 'MTA_302427'},
#           {'ExpectedArrivalTime': '2017-09-21T12:32:40.250-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6639.55,
#              'DistanceFromCall': 1790.76,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'FULTON ST/FT GREENE PL',
#            'StopPointRef': 'MTA_302428'},
#           {'ExpectedArrivalTime': '2017-09-21T12:34:22.050-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6938.8,
#              'DistanceFromCall': 2090.01,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'FULTON ST/HUDSON AV',
#            'StopPointRef': 'MTA_302430'},
#           {'ExpectedArrivalTime': '2017-09-21T12:36:37.650-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7188.7,
#              'DistanceFromCall': 2339.92,
#              'PresentableDistance': '1.5 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302431'},
#           {'ExpectedArrivalTime': '2017-09-21T12:38:11.050-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7394.01,
#              'DistanceFromCall': 2545.22,
#              'PresentableDistance': '1.6 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'FULTON ST/DUFFIELD ST',
#            'StopPointRef': 'MTA_307492'},
#           {'ExpectedArrivalTime': '2017-09-21T12:39:45.250-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7604.3,
#              'DistanceFromCall': 2755.51,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'FULTON ST/JAY ST',
#            'StopPointRef': 'MTA_302433'},
#           {'ExpectedArrivalTime': '2017-09-21T12:43:00.250-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7929.74,
#              'DistanceFromCall': 3080.95,
#              'PresentableDistance': '1.9 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'JORALEMON ST/COURT ST',
#            'StopPointRef': 'MTA_302434'},
#           {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8059.65,
#              'DistanceFromCall': 3210.86,
#              'PresentableDistance': '2.0 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2017-09-21T12:44:37.050-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8097.91,
#              'DistanceFromCall': 3249.12,
#              'PresentableDistance': '2.0 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
#            'StopPointRef': 'MTA_901463'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.685252, 'Longitude': -73.958964},
#         'VehicleRef': 'MTA NYCT_4046'},
#        'RecordedAtTime': '2017-09-21T12:21:35.386-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 186.5775,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_26340_B52-119',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-070000_B52_108'},
#         'JourneyPatternRef': 'MTA_B520048',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:22:21.802-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:22:21.802-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 6075.28,
#            'DistanceFromCall': 51.19,
#            'PresentableDistance': 'approaching',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GREENE AV/ADELPHI ST',
#          'StopPointRef': 'MTA_307576',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:22:20.802-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6075.28,
#              'DistanceFromCall': 51.19,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307576'},
#           {'ExpectedArrivalTime': '2017-09-21T12:23:10.008-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6239.48,
#              'DistanceFromCall': 215.39,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GREENE AV/CUMBERLAND ST',
#            'StopPointRef': 'MTA_307577'},
#           {'ExpectedArrivalTime': '2017-09-21T12:24:50.355-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6482.4,
#              'DistanceFromCall': 458.31,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'FULTON ST/S ELLIOTT PL',
#            'StopPointRef': 'MTA_302427'},
#           {'ExpectedArrivalTime': '2017-09-21T12:26:01.018-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6639.55,
#              'DistanceFromCall': 615.46,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'FULTON ST/FT GREENE PL',
#            'StopPointRef': 'MTA_302428'},
#           {'ExpectedArrivalTime': '2017-09-21T12:27:42.818-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6938.8,
#              'DistanceFromCall': 914.72,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'FULTON ST/HUDSON AV',
#            'StopPointRef': 'MTA_302430'},
#           {'ExpectedArrivalTime': '2017-09-21T12:29:58.418-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7188.7,
#              'DistanceFromCall': 1164.62,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302431'},
#           {'ExpectedArrivalTime': '2017-09-21T12:31:31.818-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7394.01,
#              'DistanceFromCall': 1369.92,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'FULTON ST/DUFFIELD ST',
#            'StopPointRef': 'MTA_307492'},
#           {'ExpectedArrivalTime': '2017-09-21T12:33:06.018-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7604.3,
#              'DistanceFromCall': 1580.21,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'FULTON ST/JAY ST',
#            'StopPointRef': 'MTA_302433'},
#           {'ExpectedArrivalTime': '2017-09-21T12:36:21.018-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7929.74,
#              'DistanceFromCall': 1905.65,
#              'PresentableDistance': '1.2 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'JORALEMON ST/COURT ST',
#            'StopPointRef': 'MTA_302434'},
#           {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8059.65,
#              'DistanceFromCall': 2035.56,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2017-09-21T12:37:57.818-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8097.91,
#              'DistanceFromCall': 2073.82,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
#            'StopPointRef': 'MTA_901463'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.686196, 'Longitude': -73.970281},
#         'VehicleRef': 'MTA NYCT_6530'},
#        'RecordedAtTime': '2017-09-21T12:21:55.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 186.55295,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_27240_B52-124',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-072000_B52_114'},
#         'JourneyPatternRef': 'MTA_B520048',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:22:27.788-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:22:27.788-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 3177.93,
#            'DistanceFromCall': 54.09,
#            'PresentableDistance': 'approaching',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#          'StopPointRef': 'MTA_306530',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:22:27.788-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3177.93,
#              'DistanceFromCall': 54.09,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_306530'},
#           {'ExpectedArrivalTime': '2017-09-21T12:23:33.188-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3373.19,
#              'DistanceFromCall': 249.36,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_304209'},
#           {'ExpectedArrivalTime': '2017-09-21T12:25:23.988-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3659.93,
#              'DistanceFromCall': 536.09,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_304210'},
#           {'ExpectedArrivalTime': '2017-09-21T12:26:57.588-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3902.63,
#              'DistanceFromCall': 778.8,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_304211'},
#           {'ExpectedArrivalTime': '2017-09-21T12:28:44.619-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4182.76,
#              'DistanceFromCall': 1058.92,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_304212'},
#           {'ExpectedArrivalTime': '2017-09-21T12:30:44.271-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4496.51,
#              'DistanceFromCall': 1372.68,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_304213'},
#           {'ExpectedArrivalTime': '2017-09-21T12:32:10.602-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4675.5,
#              'DistanceFromCall': 1551.67,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_304214'},
#           {'ExpectedArrivalTime': '2017-09-21T12:33:09.899-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4864.08,
#              'DistanceFromCall': 1740.25,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GATES AV/CLASSON AV',
#            'StopPointRef': 'MTA_307948'},
#           {'ExpectedArrivalTime': '2017-09-21T12:34:49.699-04:00',
# ...
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2017-09-21T12:28:09.120-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8097.91,
#              'DistanceFromCall': 646.13,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
#            'StopPointRef': 'MTA_901463'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.69075, 'Longitude': -73.985576},
#         'VehicleRef': 'MTA NYCT_6569'},
#        'RecordedAtTime': '2017-09-21T12:22:09.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 6.437822,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_23880_B52-112',
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-072300_B52_110'},
#         'JourneyPatternRef': 'MTA_B520040',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:23:05.528-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:23:05.528-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 2849.35,
#            'DistanceFromCall': 156.44,
#            'PresentableDistance': '< 1 stop away',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GREENE AV/WASHINGTON AV',
#          'StopPointRef': 'MTA_307550',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:23:05.528-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2849.35,
#              'DistanceFromCall': 156.44,
#              'PresentableDistance': '< 1 stop away',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307550'},
#           {'ExpectedArrivalTime': '2017-09-21T12:24:17.019-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3107.79,
#              'DistanceFromCall': 414.87,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307551'},
#           {'ExpectedArrivalTime': '2017-09-21T12:25:22.419-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3346.41,
#              'DistanceFromCall': 653.5,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307552'},
#           {'ExpectedArrivalTime': '2017-09-21T12:26:26.804-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3579.59,
#              'DistanceFromCall': 886.68,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'FRANKLIN AV/GREENE AV',
#            'StopPointRef': 'MTA_307553'},
#           {'ExpectedArrivalTime': '2017-09-21T12:27:24.115-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3827.24,
#              'DistanceFromCall': 1134.33,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_307674'},
#           {'ExpectedArrivalTime': '2017-09-21T12:28:21.482-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4010.77,
#              'DistanceFromCall': 1317.86,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_307675'},
#           {'ExpectedArrivalTime': '2017-09-21T12:29:20.407-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4274.94,
#              'DistanceFromCall': 1582.03,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_307676'},
#           {'ExpectedArrivalTime': '2017-09-21T12:30:57.982-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4600.33,
#              'DistanceFromCall': 1907.42,
#              'PresentableDistance': '1.2 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_307677'},
#           {'ExpectedArrivalTime': '2017-09-21T12:32:17.982-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4849.89,
#              'DistanceFromCall': 2156.98,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_307678'},
#           {'ExpectedArrivalTime': '2017-09-21T12:33:30.920-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5087.05,
#              'DistanceFromCall': 2394.14,
#              'PresentableDistance': '1.5 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_307679'},
#           {'ExpectedArrivalTime': '2017-09-21T12:35:01.762-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5326.1,
#              'DistanceFromCall': 2633.19,
#              'PresentableDistance': '1.6 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_307680'},
#           {'ExpectedArrivalTime': '2017-09-21T12:36:21.562-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5574.85,
#              'DistanceFromCall': 2881.93,
#              'PresentableDistance': '1.8 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'GATES AV/LEWIS AV',
#            'StopPointRef': 'MTA_307681'},
#           {'ExpectedArrivalTime': '2017-09-21T12:37:41.362-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5826.46,
#              'DistanceFromCall': 3133.55,
#              'PresentableDistance': '1.9 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'GATES AV/STUYVESANT AV',
#            'StopPointRef': 'MTA_307682'},
#           {'ExpectedArrivalTime': '2017-09-21T12:39:13.562-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6075.85,
#              'DistanceFromCall': 3382.94,
#              'PresentableDistance': '2.1 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'GATES AV/MALCOLM X BL',
#            'StopPointRef': 'MTA_307683'},
#           {'ExpectedArrivalTime': '2017-09-21T12:40:07.794-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6321.91,
#              'DistanceFromCall': 3629.0,
#              'PresentableDistance': '2.3 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'GATES AV/PATCHEN AV',
#            'StopPointRef': 'MTA_307684'},
#           {'ExpectedArrivalTime': '2017-09-21T12:41:13.307-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6555.96,
#              'DistanceFromCall': 3863.05,
#              'PresentableDistance': '2.4 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'GATES AV/RALPH AV',
#            'StopPointRef': 'MTA_307901'},
#           {'ExpectedArrivalTime': '2017-09-21T12:42:15.307-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6717.8,
#              'DistanceFromCall': 4024.89,
#              'PresentableDistance': '2.5 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_307686'},
#           {'ExpectedArrivalTime': '2017-09-21T12:44:07.939-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6962.31,
#              'DistanceFromCall': 4269.4,
#              'PresentableDistance': '2.7 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_307687'},
#           {'ExpectedArrivalTime': '2017-09-21T12:45:17.939-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7131.71,
#              'DistanceFromCall': 4438.79,
#              'PresentableDistance': '2.8 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_307688'},
#           {'ExpectedArrivalTime': '2017-09-21T12:46:19.923-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7373.59,
#              'DistanceFromCall': 4680.68,
#              'PresentableDistance': '2.9 miles away',
#              'StopsFromCall': 19}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2017-09-21T12:47:24.627-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7576.02,
#              'DistanceFromCall': 4883.11,
#              'PresentableDistance': '3.0 miles away',
#              'StopsFromCall': 20}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2017-09-21T12:48:17.827-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7782.09,
#              'DistanceFromCall': 5089.18,
#              'PresentableDistance': '3.2 miles away',
#              'StopsFromCall': 21}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2017-09-21T12:49:47.193-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8081.37,
#              'DistanceFromCall': 5388.46,
#              'PresentableDistance': '3.3 miles away',
#              'StopsFromCall': 22}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2017-09-21T12:50:22.593-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8231.28,
#              'DistanceFromCall': 5538.37,
#              'PresentableDistance': '3.4 miles away',
#              'StopsFromCall': 23}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.686578, 'Longitude': -73.966951},
#         'VehicleRef': 'MTA NYCT_6563'},
#        'RecordedAtTime': '2017-09-21T12:22:08.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 6.5566864,
#         'BlockRef': 'MTA NYCT_FP_D7-Weekday_C_FP_17400_B52-104',
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2017-09-21',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D7-Weekday-070300_B26_5'},
#         'JourneyPatternRef': 'MTA_B520040',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2017-09-21T12:22:43.545-04:00',
#          'ExpectedDepartureTime': '2017-09-21T12:22:43.545-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 6321.91,
#            'DistanceFromCall': 242.94,
#            'PresentableDistance': '< 1 stop away',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/PATCHEN AV',
#          'StopPointRef': 'MTA_307684',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2017-09-21T12:22:43.545-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6321.91,
#              'DistanceFromCall': 242.94,
#              'PresentableDistance': '< 1 stop away',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/PATCHEN AV',
#            'StopPointRef': 'MTA_307684'},
#           {'ExpectedArrivalTime': '2017-09-21T12:23:49.058-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6555.96,
#              'DistanceFromCall': 476.99,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/RALPH AV',
#            'StopPointRef': 'MTA_307901'},
#           {'ExpectedArrivalTime': '2017-09-21T12:24:51.058-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6717.8,
#              'DistanceFromCall': 638.83,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_307686'},
#           {'ExpectedArrivalTime': '2017-09-21T12:26:43.690-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6962.31,
#              'DistanceFromCall': 883.34,
#              'PresentableDistance': '0.5 miles away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_307687'},
#           {'ExpectedArrivalTime': '2017-09-21T12:27:53.690-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7131.71,
#              'DistanceFromCall': 1052.74,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_307688'},
#           {'ExpectedArrivalTime': '2017-09-21T12:28:55.674-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7373.59,
#              'DistanceFromCall': 1294.62,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2017-09-21T12:30:00.378-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7576.02,
#              'DistanceFromCall': 1497.05,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2017-09-21T12:30:53.578-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7782.09,
#              'DistanceFromCall': 1703.13,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2017-09-21T12:32:22.944-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8081.37,
#              'DistanceFromCall': 2002.41,
#              'PresentableDistance': '1.2 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2017-09-21T12:32:58.344-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8231.28,
#              'DistanceFromCall': 2152.31,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.688617, 'Longitude': -73.929715},
#         'VehicleRef': 'MTA NYCT_3985'},
#        'RecordedAtTime': '2017-09-21T12:21:50.000-04:00'}]}]}}}
