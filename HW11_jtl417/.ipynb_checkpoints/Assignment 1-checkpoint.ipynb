# %%
import numpy as np
import pandas as pd
import pylab as pl
import pandas as pd
import zipfile 
import urllib
import os
import geopandas as gpd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Part 1: Data Cleaning

# %%
# !for ((y=94; y<=99; y+=1)); do wget \
https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp$y\totals.zip; done

# !for ((y=0; y<=1; y+=1)); do wget \
https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp0$y\totals.zip; done

# !for ((y=2; y<=9; y+=1)); do wget \
https://www2.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=10; y<=14; y+=1)); do wget \
https://www2.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2017-12-12 11:12:07--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp94totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 611524 (597K) [application/zip]
# Saving to: “zbp94totals.zip”
#
# 100%[======================================>] 611,524     --.-K/s   in 0.04s
#
# 2017-12-12 11:12:07 (16.2 MB/s) - “zbp94totals.zip” saved [611524/611524]
#
# --2017-12-12 11:12:07--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp95totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625328 (611K) [application/zip]
# Saving to: “zbp95totals.zip”
#
# 100%[======================================>] 625,328     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:07 (18.7 MB/s) - “zbp95totals.zip” saved [625328/625328]
#
# --2017-12-12 11:12:07--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp96totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 632625 (618K) [application/zip]
# Saving to: “zbp96totals.zip”
#
# 100%[======================================>] 632,625     --.-K/s   in 0.04s
#
# 2017-12-12 11:12:07 (16.7 MB/s) - “zbp96totals.zip” saved [632625/632625]
#
# --2017-12-12 11:12:07--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp97totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629368 (615K) [application/zip]
# Saving to: “zbp97totals.zip”
#
# 100%[======================================>] 629,368     --.-K/s   in 0.02s
#
# 2017-12-12 11:12:07 (25.7 MB/s) - “zbp97totals.zip” saved [629368/629368]
#
# --2017-12-12 11:12:07--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp98totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 617784 (603K) [application/zip]
# Saving to: “zbp98totals.zip”
#
# 100%[======================================>] 617,784     --.-K/s   in 0.1s
#
# 2017-12-12 11:12:07 (4.72 MB/s) - “zbp98totals.zip” saved [617784/617784]
#
# --2017-12-12 11:12:07--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp99totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625814 (611K) [application/zip]
# Saving to: “zbp99totals.zip”
#
# 100%[======================================>] 625,814     --.-K/s   in 0.1s
#
# 2017-12-12 11:12:08 (5.45 MB/s) - “zbp99totals.zip” saved [625814/625814]
#
# --2017-12-12 11:12:08--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp00totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628434 (614K) [application/zip]
# Saving to: “zbp00totals.zip”
#
# 100%[======================================>] 628,434     --.-K/s   in 0.1s
#
# 2017-12-12 11:12:08 (5.23 MB/s) - “zbp00totals.zip” saved [628434/628434]
#
# --2017-12-12 11:12:08--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV//zbp01totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628815 (614K) [application/zip]
# Saving to: “zbp01totals.zip”
#
# 100%[======================================>] 628,815     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:08 (23.1 MB/s) - “zbp01totals.zip” saved [628815/628815]
#
# --2017-12-12 11:12:08--  https://www2.census.gov/econ2002/CBP_CSV/zbp02totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 620754 (606K) [application/zip]
# Saving to: “zbp02totals.zip.1”
#
# 100%[======================================>] 620,754     --.-K/s   in 0.04s
#
# 2017-12-12 11:12:08 (13.3 MB/s) - “zbp02totals.zip.1” saved [620754/620754]
#
# --2017-12-12 11:12:08--  https://www2.census.gov/econ2003/CBP_CSV/zbp03totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 622790 (608K) [application/zip]
# Saving to: “zbp03totals.zip”
#
# 100%[======================================>] 622,790     --.-K/s   in 0.02s
#
# 2017-12-12 11:12:08 (24.2 MB/s) - “zbp03totals.zip” saved [622790/622790]
#
# --2017-12-12 11:12:08--  https://www2.census.gov/econ2004/CBP_CSV/zbp04totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625803 (611K) [application/zip]
# Saving to: “zbp04totals.zip”
#
# 100%[======================================>] 625,803     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:08 (23.7 MB/s) - “zbp04totals.zip” saved [625803/625803]
#
# --2017-12-12 11:12:08--  https://www2.census.gov/econ2005/CBP_CSV/zbp05totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 627583 (613K) [application/zip]
# Saving to: “zbp05totals.zip”
#
# 100%[======================================>] 627,583     --.-K/s   in 0.04s
#
# 2017-12-12 11:12:08 (13.9 MB/s) - “zbp05totals.zip” saved [627583/627583]
#
# --2017-12-12 11:12:08--  https://www2.census.gov/econ2006/CBP_CSV/zbp06totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629107 (614K) [application/zip]
# Saving to: “zbp06totals.zip”
#
# 100%[======================================>] 629,107     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:09 (23.3 MB/s) - “zbp06totals.zip” saved [629107/629107]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2007/CBP_CSV/zbp07totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667754 (652K) [application/zip]
# Saving to: “zbp07totals.zip”
#
# 100%[======================================>] 667,754     --.-K/s   in 0.02s
#
# 2017-12-12 11:12:09 (30.4 MB/s) - “zbp07totals.zip” saved [667754/667754]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2008/CBP_CSV/zbp08totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 663242 (648K) [application/zip]
# Saving to: “zbp08totals.zip”
#
# 100%[======================================>] 663,242     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:09 (20.7 MB/s) - “zbp08totals.zip” saved [663242/663242]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2009/CBP_CSV/zbp09totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 660109 (645K) [application/zip]
# Saving to: “zbp09totals.zip”
# 100%[======================================>] 660,109     --.-K/s   in 0.05s
#
# 2017-12-12 11:12:09 (12.9 MB/s) - “zbp09totals.zip” saved [660109/660109]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2010/CBP_CSV/zbp10totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797534 (779K) [application/zip]
# Saving to: “zbp10totals.zip”
#
# 100%[======================================>] 797,534     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:09 (25.1 MB/s) - “zbp10totals.zip” saved [797534/797534]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2011/CBP_CSV/zbp11totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 795390 (777K) [application/zip]
# Saving to: “zbp11totals.zip”
#
# 100%[======================================>] 795,390     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:09 (22.9 MB/s) - “zbp11totals.zip” saved [795390/795390]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2012/CBP_CSV/zbp12totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733541 (716K) [application/zip]
# Saving to: “zbp12totals.zip”
#
# 100%[======================================>] 733,541     --.-K/s   in 0.08s
#
# 2017-12-12 11:12:09 (8.52 MB/s) - “zbp12totals.zip” saved [733541/733541]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2013/CBP_CSV/zbp13totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733605 (716K) [application/zip]
# Saving to: “zbp13totals.zip”
#
# 100%[======================================>] 733,605     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:09 (23.1 MB/s) - “zbp13totals.zip” saved [733605/733605]
#
# --2017-12-12 11:12:09--  https://www2.census.gov/econ2014/CBP_CSV/zbp14totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733763 (717K) [application/zip]
# Saving to: “zbp14totals.zip”
#
# 100%[======================================>] 733,763     --.-K/s   in 0.03s
#
# 2017-12-12 11:12:10 (24.5 MB/s) - “zbp14totals.zip” saved [733763/733763]

# %%
# !wget https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip
# Out:
# --2017-12-12 11:00:34--  https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip
# Resolving data.cityofnewyork.us... 52.206.140.199
# Connecting to data.cityofnewyork.us|52.206.140.199|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.cityofnewyork.us/api/views/i8iw-xf4u/files/YObIR0MbpUVA0EpQzZSq5x55FzKGM2ejSeahdvjqR20?filename=ZIP_CODE_040114.zip [following]
# --2017-12-12 11:00:35--  https://data.cityofnewyork.us/api/views/i8iw-xf4u/files/YObIR0MbpUVA0EpQzZSq5x55FzKGM2ejSeahdvjqR20?filename=ZIP_CODE_040114.zip
# Connecting to data.cityofnewyork.us|52.206.140.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1514401 (1.4M) [application/octet-stream]
# Saving to: “application%2Fzip”
#
# 100%[======================================>] 1,514,401   1.95M/s   in 0.7s
#
# 2017-12-12 11:00:36 (1.95 MB/s) - “application%2Fzip” saved [1514401/1514401]

# %%
frames = []
for i in range(94,100):
    fname = 'zbp' + str(i) + "totals.zip"
    zf = zipfile.ZipFile(fname)
    df = pd.read_csv(zf.open(fname.replace('.zip','.txt')))
    df.columns = [x.lower() for x in df.columns]
    df = df[df.zip.astype(str).str.startswith('1')]
    #df.zip = df.zip.apply(add_zeros)
    df.set_index('zip', inplace=True)
    df = df['est'].rename('19' + str(i))
    frames.append(df)

for i in range(0,15):
    fname = 'zbp' + str(i).zfill(2) + "totals.zip"
    zf = zipfile.ZipFile(fname)
    df = pd.read_csv(zf.open(fname.replace('.zip','.txt')))
    df.columns = [x.lower() for x in df.columns]
    df = df[df.zip.astype(str).str.startswith('1')]
    #df.zip = df.zip.apply(add_zeros)
    df.set_index('zip', inplace=True)
    df = df['est'].rename('20' + str(i).zfill(2))
    frames.append(df)

# %%
df = pd.concat(frames, axis=1)
#del df.index.name

# %%
url = "https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip"
urllib.request.urlretrieve(url, 'nyc.zip')
os.system("unzip -d %s nyc.zip"%(os.getenv("PUIDATA")))

nycshp = gpd.GeoDataFrame.from_file((os.getenv("PUIDATA") + "/ZIP_CODE_040114.shp"))

# %%
nycshp.ZIPCODE = nycshp.ZIPCODE.astype(int)

# %%
df["ZIPCODE"] = df.index

# %%
df = df.merge(nycshp, on="ZIPCODE")

# %%
df.set_index("ZIPCODE", inplace=True)

# %% [markdown]
# # Part 2: K-Means Clustering

# %%
cluster = df.ix[:,:21]

# %%
cluster = cluster.dropna()

# %%
for i in range(0,len(cluster.columns)):
    ts = np.asarray(cluster.ix[:,i])
    mean = ts.mean()
    std = ts.std()
    for j in range(0,len(ts)):
        ts[j] = (ts[j] - mean)/std
    cluster.ix[:,i] = ts

# %%
from scipy.spatial.distance import cdist, pdist
from sklearn.cluster import KMeans

def elbow(data,K):
#data is your input as numpy form
#K is a list of number of clusters you would like to show.
    # Run the KMeans model and save all the results for each number of clusters
    KM = [KMeans(n_clusters=k).fit(data) for k in K]
    
    # Save the centroids for each model with a increasing k
    centroids = [k.cluster_centers_ for k in KM]

    # For each k, get the distance between the data with each center. 
    D_k = [cdist(data, cent, 'euclidean') for cent in centroids]
    
    # But we only need the distance to the nearest centroid since we only calculate dist(x,ci) for its own cluster.
    globals()['dist'] = [np.min(D,axis=1) for D in D_k]
    
    # Calculate the Average SSE.
    avgWithinSS = [sum(d)/data.shape[0] for d in dist]
    
    
    # elbow curve
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(K, avgWithinSS, 'b*-')
    plt.grid(True)
    plt.xlabel('Number of clusters')
    plt.ylabel('Average within-cluster sum of squares')
    plt.title('Elbow for KMeans clustering')
    plt.show()
    
    
    # Total with-in sum of square plot. Another way to show the result.
    wcss = [sum(d**2) for d in dist]
    tss = sum(pdist(data)**2)/data.shape[0]
    bss = tss-wcss
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(K, bss/tss*100, 'b*-')
    plt.grid(True)
    plt.xlabel('Number of clusters')
    plt.ylabel('Percentage of variance explained')
    plt.title('Elbow for KMeans clustering')
    plt.show()

# %%
elbow(cluster,range(1,20))

# %% [markdown]
# Elbow curve suggest 3 clusters - % variance explained at 3 is ~ 85%, and same for 4: therefore 3 clusters makes sense.

# %%
clusterer = KMeans(n_clusters=3, random_state=324)
cluster_labels = clusterer.fit_predict(cluster)
cluster['cluster_labels'] = cluster_labels

# %%
cluster["ZIPCODE"] = cluster.index

# %%
df = df.join(cluster.cluster_labels)

# %%
df = gpd.GeoDataFrame(df)

# %%
df.plot(column='cluster_labels', cmap='Reds', legend=True)
plt.title("Clusters: K Means")
# Out:
# Text(0.5,1,'Clusters: K Means')

# %%
cluster_label_group = df.groupby("cluster_labels").mean()

# %%
cluster_label_group.ix[:,0:21]
# Out:
#                        1994         1995         1996         1997  \
# cluster_labels
# 0.0              341.055814   346.162791   351.697674   359.744186
# 1.0             5317.000000  5455.909091  5461.818182  5577.727273
# 2.0             1388.192982  1413.526316  1437.368421  1482.157895
#
#                        1998         1999         2000         2001  \
# cluster_labels
# 0.0              364.432558   367.795349   371.865116   371.158140
# 1.0             5616.181818  5600.545455  5690.454545  5695.272727
# 2.0             1506.807018  1538.350877  1581.245614  1580.263158
#
#                        2002         2003     ...              2005  \
# cluster_labels                               ...
# 0.0              384.906977   391.734884     ...        400.353488
# 1.0             5487.363636  5475.818182     ...       5581.363636
# 2.0             1615.035088  1638.701754     ...       1682.087719
#
#                        2006         2007         2008         2009  \
# cluster_labels
# 0.0              402.311628   407.906977   412.688372   419.339535
# 1.0             5618.909091  5510.363636  5483.181818  5387.727273
# 2.0             1701.228070  1727.385965  1742.456140  1756.894737
#
#                        2010         2011         2012         2013  \
# cluster_labels
# 0.0              428.753488   435.911628   445.786047   457.013953
# 1.0             5358.363636  5345.909091  5360.272727  5387.909091
# 2.0             1792.245614  1819.157895  1859.596491  1900.894737
#
#                        2014
# cluster_labels
# 0.0              466.162791
# 1.0             5404.454545
# 2.0             1947.350877
#
# [3 rows x 21 columns]

# %%
plt.figure(figsize=(12,10))
plt.plot(cluster_label_group.ix[:,0:21].T)
plt.title("Cluster Centers Over Time: K Means")
plt.legend([0,1,2])

# %% [markdown]
# # Part 3: Clustering Using Gaussian Mixture

# %%
from sklearn import mixture

# %%
g = mixture.GMM(n_components=3)
g.fit(cluster)
# Out:
# GMM(covariance_type='diag', init_params='wmc', min_covar=0.001,
#   n_components=3, n_init=1, n_iter=100, params='wmc', random_state=None,
#   thresh=None, tol=0.001, verbose=0)

# %%
cluster_labels = g.predict(cluster)

# %%
cluster["Cluster_Labels_GaussianMixture"] = cluster_labels

# %%
df = df.join(cluster.Cluster_Labels_GaussianMixture)

# %%
df.plot(column = "Cluster_Labels_GaussianMixture", cmap = "Reds", legend = True)
plt.title("Clusters: Gaussian Mixture")
# Out:
# Text(0.5,1,'Clusters: Gaussian Mixture')

# %%
cluster_label_group_1 = df.groupby("Cluster_Labels_GaussianMixture").mean()

# %%
plt.figure(figsize=(12,10))
plt.plot(cluster_label_group_1.ix[:,0:21].T)
plt.title("Cluster Centers Over Time: Gaussian Mixture")
plt.legend([0,1,2])
